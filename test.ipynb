# %%
import pandas as pd
comments_df = pd.read_csv('files/compiled_comments_3_14_2021.csv')
comments_df
# Out:
#        action                                            content  \
# 0        True  So what are the implications here? Does it onl...
# 1        True  Sadly this isn't new. Police officers use many...
# 2        True  What's disturbing about this is that our gover...
# 3        True  What I find really concerning is the horrible ...
# 4        True  This subject might have legs but this article ...
# ...       ...                                                ...
# 10231    True  Yes, while in East Baghdad my platoons mission...
# 10232    True  The [definition the FBI currently uses for int...
# 10233    True  [Yes.](https://en.m.wikipedia.org/wiki/Islamic...
# 10234    True  Has ANY Shia ever committed an act of terroris...
# 10235    True  It would not be constitutional in my opinion. ...
#
#                      author details submissionId commentId  WordScore  \
# 0                Cody_Fox23     NaN       4op948   d4eictg   0.000000
# ...

# %%
no_profane_comments_df = comments_df[comments_df['profanity'] == False]

# %%
profane_comments_df = comments_df[comments_df['profanity'] == True]

# %%
profane_comments_df
# Out:
#        action                                            content  \
# 82       True  What's most disheartening to me is the fact th...
# 97       True  Unpopular opinion: I like Warren, I think she'...
# 102      True  Yes let's stop and think for a moment.\n\n[The...
# 107      True  I'm hesitant to get in on this 'fuck the rich'...
# 118      True  [A news article](https://www.burlingtonfreepre...
# ...       ...                                                ...
# 9992     True  I believe the rationale behind Roe v. Wade was...
# 10062    True  Although I support reducing/subsidizing colleg...
# 10064    True  If this works out, how does it affect people w...
# 10070    True  Con. I’ve already paid my loans off. That burd...
# 10233    True  [Yes.](https://en.m.wikipedia.org/wiki/Islamic...
#
#                      author details submissionId commentId  WordScore  \
# 82               Katholikos     NaN       9kq8xy   e71ac41   0.165953
# ...

# %%
n
# Out:
# "What's most disheartening to me is the fact that this isn't as simple as trying to force couples to get married or be separated. According to the source article, only 12% of UN member-states allow [same sex marriage](https://twitter.com/SamanthaJPower/status/1045756345822191616). If there's any chance that these diplomats might need to work in a country that doesn't allow it, they actually *can't* get married without potentially causing significant issues in their careers. That's a shitty situation to force someone into."
