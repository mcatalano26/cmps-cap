# %%
import pandas as pd

# %%
comments = pd.read_csv('files/compiled_comments_3_14_2021.csv')
comments
# Out:
#        Unnamed: 0  action                                            content  \
# 0               0    True  So what are the implications here? Does it onl...
# 1               1    True  Sadly this isn't new. Police officers use many...
# 2               2    True  What's disturbing about this is that our gover...
# 3               3    True  What I find really concerning is the horrible ...
# 4               4    True  This subject might have legs but this article ...
# ...           ...     ...                                                ...
# 10231       10231    True  Yes, while in East Baghdad my platoons mission...
# 10232       10232    True  The [definition the FBI currently uses for int...
# 10233       10233    True  [Yes.](https://en.m.wikipedia.org/wiki/Islamic...
# 10234       10234    True  Has ANY Shia ever committed an act of terroris...
# 10235       10235    True  It would not be constitutional in my opinion. ...
#
# ...

# %%
comments['length'] = comments['content'].str.len()
comments['length'] = comments['length'].fillna(0)
comments
# Out:
#        Unnamed: 0  action                                            content  \
# 0               0    True  So what are the implications here? Does it onl...
# 1               1    True  Sadly this isn't new. Police officers use many...
# 2               2    True  What's disturbing about this is that our gover...
# 3               3    True  What I find really concerning is the horrible ...
# 4               4    True  This subject might have legs but this article ...
# ...           ...     ...                                                ...
# 10231       10231    True  Yes, while in East Baghdad my platoons mission...
# 10232       10232    True  The [definition the FBI currently uses for int...
# 10233       10233    True  [Yes.](https://en.m.wikipedia.org/wiki/Islamic...
# 10234       10234    True  Has ANY Shia ever committed an act of terroris...
# 10235       10235    True  It would not be constitutional in my opinion. ...
#
# ...

# %%
comments.to_csv('files/compiled_comments_3_14_2021.csv')
