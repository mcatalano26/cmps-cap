# %%
import pandas as pd
import numpy as np

# %%
swearwords_df = pd.read_csv("files/swear-words.csv")
swearwords = swearwords_df.a55hole.tolist()

allowed_words = ['gay', 'sexual', 'crack', 'sperm', 'stupid', 'damn', 'prostitute', 'sex', 'kill', 'crack', 
                'oral', 'rape', 'raped', 'screw', 'sleazy', 'murder', 'organ', 'slave', 'strip', 'butt', 'naked',
                'porn', 'bone', 'nazi', 'racy', 'bodily', 'screw', 'pot', 'weed', 'pedophile', 'rapist', 'drunk', 
                'commie', 'condom', 'thrust', 'pedophilia', 'enlargement', 'cocaine', 'beer', 'stroke', 'opium',
                'unwed', 'meth']
for word in allowed_words:
    if word in swearwords:
        swearwords.remove(word)

# %%
comments_df = pd.read_csv("files/compiled_comments_2_21_2021.csv")
comments_df.head()
# Out:
#   action                                            content        author  \
# 0    NaN  So what are the implications here? Does it onl...    Cody_Fox23
# 1    NaN  Sadly this isn't new. Police officers use many...   DrFrenchman
# 2    NaN  What's disturbing about this is that our gover...        bbakks
# 3    NaN  What I find really concerning is the horrible ...  poliscijunki
# 4    NaN  This subject might have legs but this article ...     interweb1
#
#   details submissionId commentId  WordScore  WholeScore     tfidf  \
# 0     NaN       4op948   d4eictg   0.000000    0.849655  0.001573
# 1     NaN       4sef35   d58ts90   0.000000    0.900283  0.255802
# 2     NaN       4sef35   d58y081  -0.038865    0.869078  0.000000
# 3     NaN       4sef35   d5919n8   0.000000    0.898426  0.000000
# 4     NaN       64zsim   dg6l969   0.000000    0.850127  0.000000
#
#    contains_url                                   text_without_url  \
# 0         False  So what are the implications here? Does it onl...
# 1         False  Sadly this isn't new. Police officers use many...
# 2         False  What's disturbing about this is that our gover...
# 3          True  What I find really concerning is the horrible ...
# 4         False  This subject might have legs but this article ...
#
#    article_score  comment_score  all_comments_scores  \
# 0            186             22                   22
# 1             89              6                    7
# 2             89              2                    7
# 3             89             -1                    7
# 4             86             64                   90
#
#    comment_article_score_ratio  comment_comments_score_ratio  adjWordScore
# 0                     0.118280                      1.000000      0.000000
# 1                     0.067416                      0.857143      0.000000
# 2                     0.022472                      0.285714     -0.038865
# 3                    -0.011236                     -0.142857     -0.015000
# 4                     0.744186                      0.711111      0.000000

# %%
profanity = []
for index, row in comments_df.iterrows():
    #print(index)
    if pd.notnull(row.content):
        words = row.content.split()
    else:
        words = ["fine"]
    prof_check = False
    for word in words:
        if word in swearwords:
            prof_check = True
            #print(word)
    profanity.append(prof_check)

#print(profanity)
#comments_df.iloc[1].content

# %%
comments_df['profanity'] = profanity

# %%
comments_df.head()
# Out:
#   action                                            content        author  \
# 0    NaN  So what are the implications here? Does it onl...    Cody_Fox23
# 1    NaN  Sadly this isn't new. Police officers use many...   DrFrenchman
# 2    NaN  What's disturbing about this is that our gover...        bbakks
# 3    NaN  What I find really concerning is the horrible ...  poliscijunki
# 4    NaN  This subject might have legs but this article ...     interweb1
#
#   details submissionId commentId  WordScore  WholeScore     tfidf  \
# 0     NaN       4op948   d4eictg   0.000000    0.849655  0.001573
# 1     NaN       4sef35   d58ts90   0.000000    0.900283  0.255802
# 2     NaN       4sef35   d58y081  -0.038865    0.869078  0.000000
# 3     NaN       4sef35   d5919n8   0.000000    0.898426  0.000000
# 4     NaN       64zsim   dg6l969   0.000000    0.850127  0.000000
#
#    contains_url                                   text_without_url  \
# 0         False  So what are the implications here? Does it onl...
# 1         False  Sadly this isn't new. Police officers use many...
# 2         False  What's disturbing about this is that our gover...
# 3          True  What I find really concerning is the horrible ...
# 4         False  This subject might have legs but this article ...
#
#    article_score  comment_score  all_comments_scores  \
# 0            186             22                   22
# 1             89              6                    7
# 2             89              2                    7
# 3             89             -1                    7
# 4             86             64                   90
#
#    comment_article_score_ratio  comment_comments_score_ratio  adjWordScore  \
# 0                     0.118280                      1.000000      0.000000
# 1                     0.067416                      0.857143      0.000000
# 2                     0.022472                      0.285714     -0.038865
# 3                    -0.011236                     -0.142857     -0.015000
# 4                     0.744186                      0.711111      0.000000
#
#    profanity
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
comments_df.to_csv("files/compiled_comments_2_21_2021.csv", index=False)
